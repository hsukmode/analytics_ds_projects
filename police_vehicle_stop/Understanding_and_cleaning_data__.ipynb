# %% [markdown]
# In this dataset we will analyze Sacramento police vehicle stop data. Our goal of this data project is to analyze stop data from Sacramento, specifically focusing what types of people and groups are pulled over, and later on, to see if we can predict, based on interpretable features, whether a vehicle being stopped by the police will result in an arrest or citation.

# %% [markdown]
# # Step 1: Getting the data
#
# Fortunately, the city of Sacramento has a lot of great data on its website, including police vehicle stop data. Living in the Sacramento area, it will be cool to analyze data and understand more about stops work in a city close by me.
# The link for the data is below. <br>
#
# http://data.cityofsacramento.org/datasets/a8cb4c137c824e939dca586c6dc77da9_0 <br>
#
# I have downloaded the data in csv format.

# %% [markdown]
# # Step 2: Understanding the Data

# %%
import pandas as pd
import numpy as np
import pytz
import warnings
warnings.filterwarnings('ignore')

# %%
def stop_data():
    stopdata = pd.read_csv("Sacramento_Police_Vehicle_Stop_Data.csv")
    return stopdata

# %%
stopdata = pd.read_csv("Sacramento_Police_Vehicle_Stop_Data.csv")
stopdata.head(5)
# Out:
#       Idx CitationNumber                 EntryDate StopType  \
# 0  437796            NaN  2017-07-06T05:04:02.000Z  VEHICLE
# 1  437797            NaN  2017-07-06T05:46:55.000Z  VEHICLE
# 2  437798            NaN  2017-07-06T06:05:59.000Z  VEHICLE
# 3  437799            NaN  2017-07-06T06:06:16.000Z  VEHICLE
# 4  437800            NaN  2017-07-06T06:15:39.000Z  VEHICLE
#
#                     StopDTS                                      StopCause  \
# 0  2017-07-06T04:58:00.000Z  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE
# 1  2017-07-06T05:41:00.000Z  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE
# 2  2017-07-06T05:57:00.000Z   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION
# 3  2017-07-06T05:13:00.000Z   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION
# 4  2017-07-06T06:02:00.000Z   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION
#
#   ViolationNumber SpecialCondition                    Race Gender  ...  \
# 0        22108 VC   NOT APPLICABLE  ASIAN/PACIFIC ISLANDER      F  ...
# 1           22450   NOT APPLICABLE        AFRICAN AMERICAN      F  ...
# 2           24616   NOT APPLICABLE        AFRICAN AMERICAN      M  ...
# 3           4000A   NOT APPLICABLE        AFRICAN AMERICAN      F  ...
# 4           24600   NOT APPLICABLE        AFRICAN AMERICAN      M  ...
#
#    ResultCitation ResultArrest  ResultReport  ResultAdvised  ResultFC  \
# 0           False        False         False           True     False
# 1           False        False         False           True     False
# 2           False        False         False           True     False
# 3           False        False         False           True     False
# 4           False        False         False           True     False
#
#    CadCallNumber DetentionDuration OfficerAbra LimitedLanguage   FID
# 0      17-190339                 4        4425           False  2001
# 1      17-190380                15        4294           False  2002
# 2      17-190396                10        4411           False  2003
# 3      17-190348                 5        4444           False  2004
# 4      17-190402                 5        4360           False  2005
#
# [5 rows x 36 columns]

# %% [markdown]
# Perfect! We have our data loaded into a pandas dataframe! Lets try to understand our features at the data we are working with. The link below explains some of the field in data field.

# %% [markdown]
# https://www.cityofsacramento.org/-/media/Corporate/Files/Police/Transparency/VSDF/Understanding-Vehicle-Stop-Data-Fields-and-Points-of-Collection.pdf?la=en

# %% [markdown]
# Lets go through the data column by column (there are 36), some columns we might already would understand (idx, EntryDate, etc), however some we might need to understand more.

# %%
print(stopdata.columns)
print(len(stopdata.columns))
# Out:
# Index(['Idx', 'CitationNumber', 'EntryDate', 'StopType', 'StopDTS',
#        'StopCause', 'ViolationNumber', 'SpecialCondition', 'Race', 'Gender',
#        'BirthYear', 'ExitVehicle', 'PassengerCount', 'SearchDriver',
#        'SearchPassenger', 'SearchVehicle', 'Authority', 'ConsentRequested',
#        'ConsentGranted', 'FSWeapons', 'FSDrugs', 'FSCash', 'FSVehicle',
#        'FSAlcohol', 'FSOtherProperty', 'FSNothing', 'ResultCitation',
#        'ResultArrest', 'ResultReport', 'ResultAdvised', 'ResultFC',
#        'CadCallNumber', 'DetentionDuration', 'OfficerAbra', 'LimitedLanguage',
#        'FID'],
#       dtype='object')
# 36

# %%
stopdata['StopType'].unique()
# Out:
# array(['VEHICLE'], dtype=object)

# %%
stopdata['StopCause'].value_counts()
# Out:
# REGISTRATION OR REQUIRED EQUIPMENT VIOLATION     23163
# MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE    18983
# NOT APPLICABLE                                    4033
# STATE CODE VIOLATION                              3561
# LOCAL CODE VIOLATION                               134
# Name: StopCause, dtype: int64

# %%
stopdata['SpecialCondition'].unique()
# Out:
# array(['NOT APPLICABLE', 'PRE-EXISTING KNOWLEDGE/INFORMATION',
#        'VEHICLE INSPECTION', 'CALL FOR SERVICE', 'SPECIAL DETAIL',
#        'DUI CHECKPOINT', 'BOLO'], dtype=object)

# %%
stopdata['ExitVehicle'].value_counts()
# Out:
# NO     41500
# YES     7756
# Name: ExitVehicle, dtype: int64

# %%
stopdata['PassengerCount'].value_counts()
# Out:
# 0      31046
# 1      12568
# 2       3965
# 3       1671
# 4        497
# 5         83
# 6         20
# 10        10
# 7          4
# 8          3
# 15         2
# 30         1
# 25         1
# 20         1
# 425        1
# 9          1
# Name: PassengerCount, dtype: int64

# %%
stopdata['Authority'].value_counts()
# Out:
# NOT APPLICABLE        43888
# PAROLE/PROBATION       4236
# PROBABLE CAUSE          607
# TOW INVENTORY           418
# TERRY CURSORY           393
# INCIDENT TO ARRE        311
# INCIDENT TO ARREST       21
# Name: Authority, dtype: int64

# %% [markdown]
# ### Columns:
#
# <b>Idx:</b> index of a certain stop, our primary key <br>
# <b>CitationNumber: </b>The number of a citation; looking through the data, contains null if no citation, or string of citation number <br>
# <b>EntryDate: </b>When the stop was entered into the database (in UTC) <br>
# <b>StopType: </b> The only value for this column is "VEHICLE", so it is essentially useless (see code above) <br>
# <b>StopDTS: </b>This is the time the vehicle was stopped (in UTC) <br>
# <b>StopCause: </b> Probable Cause For Stop <br>
# <b>ViolationNumber: </b>The exact violation that the driver commited <br>
# <b>SpecialCondition: </b> This adds information to StopCause; for example if the stop was a result of a DUI checkpoint or a call for inspection <br>
# <b>Race: </b>Race of driver stopped (ASIAN, WHITE, etc.) <br>
# <b>Gender: </b>Gender of driver stopped (F, M) <br>
# <b>BirthYear: </b>birth year of driver <br>
# <b>ExitVehicle: </b>Binary Variable, indicates whether driver had to exit vehicle <br>
# <b>PassengerCount: </b>Number of passengers in the vehicle (not including driver)  <br>
# <b>SearchDriver: </b>binary variable, indicates if driver was searched <br>
# <b>SearchPassenger: </b>binary variable, indicates if passenger was searched<br>
# <b>SearchVehicle: </b>binary variable, indicates if vehicle was searched<br>
# <b>ConsentRequested: </b> binary variable, whether or not officer requested to search vehicle ? <br>
# <b>ConsentGranted: </b>binary variable, whether or not driver granted request to search vehicle ? <br>
# <b> CadCallNumber: </b> Report number, this should be unique <br>
# <b> DetentionDuration: </b> Amount of time spent during the stop, in minutes </b> <br>
# <b> LimitedLanguage: </b> Binary variable, indicates if driver had limited language <br>
# <b> FID: </b> Unique Identifier </b> <br>
# <b> FS columns (Weapons, alchohol, etc): </b> If search was done, what was discovered/seized? <br>
# <b> Result columns (Citation, Arrest, Advised, etc): </b>Result <br>
# <b> OfficerAbra: </b> Unique Officer Identifier <br>
# <b>Authority: </b>Primary Search Authority <br>

# %% [markdown]
# # Step 3: Cleaning the Data
#
# Because most likely we will have to run cells a lot to manipulate values in each column- the code needs to be reusable- it is best to write our cleaning data as functions and then later add all our functions to a data pipeline before we export the file back as a csv. From a software engineering perspective, this means abstracting parts of our code into reusable functions/

# %%
### check for columns where we will have to deal with missing data
for i in stopdata.columns:
    print(i + " : "  + str(stopdata[i].isna().sum()) )
# Out:
# Idx : 0
# CitationNumber : 32880
# EntryDate : 0
# StopType : 0
# StopDTS : 0
# StopCause : 0
# ViolationNumber : 81
# SpecialCondition : 0
# Race : 0
# Gender : 0
# BirthYear : 0
# ExitVehicle : 618
# PassengerCount : 0
# SearchDriver : 0
# SearchPassenger : 0
# SearchVehicle : 0
# Authority : 0
# ConsentRequested : 24223
# ConsentGranted : 46734
# FSWeapons : 0
# FSDrugs : 0
# FSCash : 0
# FSVehicle : 0
# FSAlcohol : 0
# FSOtherProperty : 0
# FSNothing : 0
# ResultCitation : 0
# ResultArrest : 0
# ResultReport : 0
# ResultAdvised : 0
# ResultFC : 0
# CadCallNumber : 0
# DetentionDuration : 0
# OfficerAbra : 0
# LimitedLanguage : 0
# FID : 0

# %% [markdown]
# Lets go through each column and see what data might need to be cleaned. This will be a long, tedious process, so enjoy the process.

# %% [markdown]
# ### CitationNumber
#
# As we found out earlier, citation numbers contain a lot of NANs because the majority of people don't get citations. Because we don't care about the CitationNumber, but rather if someone got a citation or not, lets change this column name to Citation, and map NANs to False and strings to True.

# %%
def citationnumberfix(data):
    data.rename(columns={'CitationNumber': 'Citation'}, inplace=True)
    data['Citation'].fillna(False, inplace=True)
    data.loc[data['Citation'] != 0, 'Citation'] = True
    return data

# %%
stopdata = citationnumberfix(stopdata)

# %%
stopdata[~stopdata['Citation'].isna()]['ResultCitation'].value_counts()
# Out:
# False    31415
# True     18459
# Name: ResultCitation, dtype: int64

# %% [markdown]
# The code above shows there is a discrepancy between CitationNumber and ResultCitation - we would expect when ResultCitation to be True, CitationNumber would always be filled, however, this is not always the case. More research needs to go into how these metrics were attained.

# %% [markdown]
# ### Dates and StopType
#
# Because we found the StopType earlier to be useless (only one value), we will drop this column as well (later on). We will convert our date columns to more interpretable variables ; month, year, day, day of week, and hour

# %%
stopdata['StopDTS'].head(5)
# Out:
# 0    2017-07-06T04:58:00.000Z
# 1    2017-07-06T05:41:00.000Z
# 2    2017-07-06T05:57:00.000Z
# 3    2017-07-06T05:13:00.000Z
# 4    2017-07-06T06:02:00.000Z
# Name: StopDTS, dtype: object

# %%
def convertdatecolumns(data, column):
    data[column] = pd.to_datetime(data[column])  
    newstop = pd.DataFrame(data[column])
    newstop.set_index(data[column], inplace=True)
    newstop.index = newstop.index.tz_convert('America/Los_Angeles')
    newstop['hour'] = newstop.index.hour
    newcol = 'Stop'
    if column == 'EntryDate': newcol = 'Entry'
    data.loc[:, newcol + 'Month'] = data[column].dt.month
    data.loc[:, newcol + 'Year'] = data[column].dt.year
    data.loc[:, newcol + 'DayofMonth'] = data[column].dt.day
    data.loc[:, newcol + 'DayofWeek'] = data[column].dt.dayofweek
    data.loc[:, newcol + 'Hour'] = newstop.index.hour
    return data

# %%
stopdata = convertdatecolumns(stopdata, 'StopDTS')
stopdata = convertdatecolumns(stopdata, 'EntryDate')

# %% [markdown]
# ### StopCause

# %%
stopdata['StopCause'].unique()
# Out:
# array(['MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE',
#        'REGISTRATION OR REQUIRED EQUIPMENT VIOLATION',
#        'LOCAL CODE VIOLATION', 'STATE CODE VIOLATION', 'NOT APPLICABLE'],
#       dtype=object)

# %%
stopdata['StopCause'].value_counts()
# Out:
# REGISTRATION OR REQUIRED EQUIPMENT VIOLATION     23163
# MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE    18983
# NOT APPLICABLE                                    4033
# STATE CODE VIOLATION                              3561
# LOCAL CODE VIOLATION                               134
# Name: StopCause, dtype: int64

# %% [markdown]
# All good here, it looks like no cleaning needs to be done for this column.

# %% [markdown]
# ### Violation Number

# %%
stopdata['ViolationNumber'].isna().sum()
# Out:
# 81

# %%
stopdata['ViolationNumber'].value_counts()[:10]
# Out:
# 4000A       5265
# 5200        3854
# 23123       3624
# 22450       3507
# CVC         3208
# 22350       2936
# 4000        1357
# 5200 VC     1274
# 23123.5     1145
# 4000A VC     917
# Name: ViolationNumber, dtype: int64

# %% [markdown]
# Right away, we notice some major problems with this feature; - for example "4000A" and "4000A VC" and "4000 CVC" mean the same thing. In addition, there are 81 Nan values. Let's try to "standardize" the data as best as we can, for simplicity we will only consider violations by there number, aka treating "4000A" the same as "4000B" - both these would be mapped to 4000.

# %%
def violationnumberfix(data):
    data.loc[data['ViolationNumber'].isna(), 'ViolationNumber'] = 'UNKNOWN'
    data['ViolationNumber'] = data['ViolationNumber'].str.replace("VC", "").str.replace(" ", "").str.replace("C", "").str.replace("A", "").str.replace("(", "").str.replace(")", "").str.replace("B", "")
    data.loc[data['ViolationNumber'] == "", 'ViolationNumber'] = 'UNKNOWN'
    replace_dict = {"4000A": "4000", 
                "4000(A)": "4000", 
                "4000AC": "4000", 
                "4000A1": "4000", 
                "4000(A)(1)": "4000",
                "4000(A)C": "4000",
                "5200A": "5200",
                "23123.5": "23123",
                "STOPSIGN": "22450",
                "SPEED": "22350",
                "BRKELIGHT": "24603",
                "WINDOWTINT": "26708",
                "NOPLTES": "5200",
                "REDLIGHT": "21453",
                "SPEEDING": "22350",
                "ELLPHONE": "23123",
                "TURNSIGNL": "22107",
                "EXPREG": "4000",
                "RKELIGHT": "24252"}

    data['ViolationNumber'].replace(replace_dict, inplace=True)
    return data

# %%
stopdata = violationnumberfix(stopdata)
stopdata['ViolationNumber'].value_counts()[:15]
# Out:
# 4000       9201
# 5200       6694
# 23123      5140
# 22450      4713
# 22350      3924
# UNKNOWN    3360
# 24252      1461
# 21453      1266
# 22107       959
# 24400       766
# 24603       749
# 26708       677
# 40001       648
# 24600       546
# 24601       477
# Name: ViolationNumber, dtype: int64

# %% [markdown]
# For know we have corrected as much as we can, it will take another few hours to clean every single value in this column or to think of an algorithm to fix this; if this model was going into production, it most certainly would be worth it to comb through all the data and fix it, however for the purposes of this project, we will leave the rest of the values as is.

# %% [markdown]
# ### SpecialCondition

# %%
stopdata['SpecialCondition'].unique()
# Out:
# array(['NOT APPLICABLE', 'PRE-EXISTING KNOWLEDGE/INFORMATION',
#        'VEHICLE INSPECTION', 'CALL FOR SERVICE', 'SPECIAL DETAIL',
#        'DUI CHECKPOINT', 'BOLO'], dtype=object)

# %% [markdown]
# All good here, it looks like no cleaning needs to be done for this column.

# %% [markdown]
# ### Race

# %%
stopdata['Race'].unique()
# Out:
# array(['ASIAN/PACIFIC ISLANDER', 'AFRICAN AMERICAN', 'HISPANIC', 'WHITE',
#        'OTHER/NOT APPARENT', 'ASIAN OTHER', 'ASIAN INDIAN', 'UNKNOWN',
#        'EAST INDIAN', 'HAWAIIAN', 'AM. IND./AL. NATIVE', 'MIXED RACE',
#        'FILIPINO', 'GUAMANIAN', 'MIDDLE EASTERN', 'VIETNAMESE',
#        'CUBAN/CARRIBEAN', 'NATIVE AMERICAN', 'PACIFIC ISLANDER', 'SAMOAN',
#        'HMONG', 'CHINESE', 'ORIENTAL/ASIAN', 'CAMBODIAN', 'JAPANESE'],
#       dtype=object)

# %% [markdown]
# All good here, it looks like no cleaning needs to be done for this column.

# %% [markdown]
# ### Gender

# %%
stopdata['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# All good here, it looks like no cleaning needs to be done for this column (will need to one hot encode later)

# %% [markdown]
# ### BirthYear

# %%
print(sorted(stopdata['BirthYear'].unique()))
# Out:
# [1900, 1916, 1919, 1921, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2009, 2016, 2017, 2018, 2019]

# %% [markdown]
# We know that that in California, the legal age for someone to drive is 15.5 - the idea that some drivers were born in 2016, 2017, 2018, 2019 is highly unlikely (these drivers would be either 0, 1, 2, or 3 based on the years we have data for). In addition, a driver who was born in 1900 would make them the oldest person in the United States, so this value is unlikely as well. Most likely these were mistakes. Because these were most likely all mistakes, we will fill them with the median value. However, lets make this value a little more interpretable to work with - we will change BirthYear to Age

# %%
def birthyearfix(data):
    years = [1900, 2016, 2017, 2018, 2019]
    data.loc[data['BirthYear'].isin(years), 'BirthYear'] = np.median(data['BirthYear'])
    
    #change birthyear to age
    data['Age'] = data['StopYear'] - data['BirthYear']
    data = data.loc[:, stopdata.columns != 'BirthYear']
    return data

# %%
stopdata = birthyearfix(stopdata)

# %%
print(sorted(stopdata['Age'].unique()))
# Out:
# [9.0, 12.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.0, 97.0, 98.0, 99.0, 101.0]

# %% [markdown]
# Great! We fixed our data! While the value of 9 is highly suspicious as well, we will leave it in because it is possible.

# %% [markdown]
# ### PassengerCount

# %%
stopdata['PassengerCount'].value_counts()
# Out:
# 0      31046
# 1      12568
# 2       3965
# 3       1671
# 4        497
# 5         83
# 6         20
# 10        10
# 7          4
# 8          3
# 15         2
# 30         1
# 25         1
# 20         1
# 425        1
# 9          1
# Name: PassengerCount, dtype: int64

# %% [markdown]
# 425 passengers seems unlikely, so we will replace this with 0

# %%
def passengercountfix(data):
    data.loc[data['PassengerCount'] == 425, 'PassengerCount'] = 0
    return data

# %%
stopdata = passengercountfix(stopdata)

# %% [markdown]
# ### ExitVehicle

# %%
stopdata.loc[stopdata['ExitVehicle'].isna()]
# Out:
#           Idx  Citation                 EntryDate StopType  \
# 32     437830     False 2017-07-07 06:36:13+00:00  VEHICLE
# 54     437852     False 2017-07-07 10:14:17+00:00  VEHICLE
# 220    438025     False 2017-07-11 05:40:36+00:00  VEHICLE
# 380    438197     False 2017-07-13 17:06:39+00:00  VEHICLE
# 382    438199     False 2017-07-13 17:11:28+00:00  VEHICLE
# 490    438310     False 2017-07-14 05:56:59+00:00  VEHICLE
# 572    438400     False 2017-07-15 12:18:33+00:00  VEHICLE
# 581    438409     False 2017-07-16 00:45:19+00:00  VEHICLE
# 648    438481     False 2017-07-17 06:00:56+00:00  VEHICLE
# 770    438603     False 2017-07-19 04:40:07+00:00  VEHICLE
# 939    439776     False 2017-07-20 15:55:22+00:00  VEHICLE
# 1098   439946     False 2017-07-22 07:28:13+00:00  VEHICLE
# 1103   439951     False 2017-07-22 11:08:37+00:00  VEHICLE
# 1454   440315     False 2017-07-26 15:54:28+00:00  VEHICLE
# 1459   440320     False 2017-07-26 18:05:44+00:00  VEHICLE
# 1735   440600     False 2017-07-28 07:21:57+00:00  VEHICLE
# 1741   440607     False 2017-07-28 09:23:00+00:00  VEHICLE
# 1742   440610     False 2017-07-28 09:43:31+00:00  VEHICLE
# 1743   440611     False 2017-07-28 09:43:33+00:00  VEHICLE
# 2105   442011     False 2017-08-11 09:05:14+00:00  VEHICLE
# 2257   442164     False 2017-08-13 12:15:20+00:00  VEHICLE
# 2302   442210     False 2017-08-14 09:42:51+00:00  VEHICLE
# 2366   442274     False 2017-08-15 06:53:17+00:00  VEHICLE
# 2472   442381     False 2017-08-16 20:16:33+00:00  VEHICLE
# 2506   442415     False 2017-08-17 06:25:54+00:00  VEHICLE
# 2577   442486     False 2017-08-18 07:47:36+00:00  VEHICLE
# 2585   442495     False 2017-08-18 13:22:32+00:00  VEHICLE
# 2761   442671     False 2017-08-21 08:34:04+00:00  VEHICLE
# 2803   442713     False 2017-08-22 08:49:14+00:00  VEHICLE
# 2897   442811     False 2017-08-23 06:23:26+00:00  VEHICLE
# ...       ...       ...                       ...      ...
# 47495  495486     False 2019-01-26 05:09:29+00:00  VEHICLE
# 47496  495487     False 2019-01-26 05:10:25+00:00  VEHICLE
# 47497  495488     False 2019-01-26 05:11:21+00:00  VEHICLE
# 47498  495489     False 2019-01-26 05:12:04+00:00  VEHICLE
# 47499  495490     False 2019-01-26 05:12:40+00:00  VEHICLE
# 47500  495491     False 2019-01-26 05:13:35+00:00  VEHICLE
# 47504  495495     False 2019-01-26 05:16:36+00:00  VEHICLE
# 47586  495577     False 2019-02-01 04:58:42+00:00  VEHICLE
# 47606  495597     False 2019-02-02 00:04:47+00:00  VEHICLE
# 47693  495684     False 2019-02-05 01:21:16+00:00  VEHICLE
# 47694  495685     False 2019-02-05 01:26:07+00:00  VEHICLE
# 47764  495755     False 2019-02-08 14:06:43+00:00  VEHICLE
# 47864  495855     False 2019-02-21 19:57:17+00:00  VEHICLE
# 47866  495857     False 2019-02-21 19:58:54+00:00  VEHICLE
# 47867  495858     False 2019-02-21 19:59:51+00:00  VEHICLE
# 48181  494286     False 2018-12-22 03:59:15+00:00  VEHICLE
# 48676  494781     False 2018-12-29 00:00:14+00:00  VEHICLE
# 48704  494809     False 2018-12-29 01:35:25+00:00  VEHICLE
# 48747  494852     False 2018-12-29 04:28:32+00:00  VEHICLE
# 48808  494913     False 2018-12-30 01:37:40+00:00  VEHICLE
# 48809  494914     False 2018-12-30 01:37:46+00:00  VEHICLE
# 48863  494968     False 2018-12-31 19:40:19+00:00  VEHICLE
# 49098  436933     False 2017-06-24 22:56:20+00:00  VEHICLE
# 49168  437003     False 2017-06-25 17:54:22+00:00  VEHICLE
# 49259  437101     False 2017-06-27 07:42:08+00:00  VEHICLE
# 49262  437104     False 2017-06-27 08:12:01+00:00  VEHICLE
# 49573  437466     False 2017-07-01 07:49:40+00:00  VEHICLE
# 49574  437467     False 2017-07-01 07:52:04+00:00  VEHICLE
# 49774  437694     False 2017-07-04 06:38:14+00:00  VEHICLE
# 49788  437708     False 2017-07-04 15:57:48+00:00  VEHICLE
#
#                         StopDTS  \
# 32    2017-07-04 23:22:00+00:00
# 54    2017-07-07 06:00:00+00:00
# 220   2017-07-11 05:27:00+00:00
# 380   2017-06-13 23:55:00+00:00
# 382   2017-06-02 23:16:00+00:00
# 490   2017-07-14 05:33:00+00:00
# 572   2017-06-26 08:34:00+00:00
# 581   2017-07-16 00:40:00+00:00
# 648   2017-07-17 05:53:00+00:00
# 770   2017-07-19 02:41:00+00:00
# 939   2017-07-20 15:47:00+00:00
# 1098  2017-07-22 07:17:00+00:00
# 1103  2017-07-22 10:59:00+00:00
# 1454  2017-07-26 15:26:00+00:00
# 1459  2017-07-26 17:52:00+00:00
# 1735  2017-07-28 07:15:00+00:00
# 1741  2017-07-28 08:54:00+00:00
# 1742  2017-07-28 09:32:00+00:00
# 1743  2017-07-28 09:32:00+00:00
# 2105  2017-08-11 08:56:00+00:00
# 2257  2017-08-13 07:35:00+00:00
# 2302  2017-08-01 08:26:00+00:00
# 2366  2017-08-15 06:31:00+00:00
# 2472  2017-07-08 08:41:00+00:00
# 2506  2017-08-17 05:52:00+00:00
# 2577  2017-08-18 07:40:00+00:00
# 2585  2017-08-18 13:08:00+00:00
# 2761  2017-08-21 08:23:00+00:00
# 2803  2017-08-22 08:42:00+00:00
# 2897  2017-08-23 06:17:00+00:00
# ...                         ...
# 47495 2018-12-21 17:16:00+00:00
# 47496 2018-12-18 17:18:00+00:00
# 47497 2018-12-18 16:53:00+00:00
# 47498 2018-12-18 16:44:00+00:00
# 47499 2018-12-11 15:17:00+00:00
# 47500 2018-12-09 05:02:00+00:00
# 47504 2018-12-07 22:01:00+00:00
# 47586 2018-11-01 17:37:00+00:00
# 47606 2018-09-04 02:03:00+00:00
# 47693 2018-12-14 03:18:00+00:00
# 47694 2018-12-13 16:58:00+00:00
# 47764 2018-09-02 06:06:00+00:00
# 47864 2018-12-21 20:14:00+00:00
# 47866 2018-12-18 21:29:00+00:00
# 47867 2018-12-14 19:58:00+00:00
# 48181 2018-11-01 06:02:00+00:00
# 48676 2018-12-28 23:50:00+00:00
# 48704 2018-10-28 02:44:00+00:00
# 48747 2018-12-29 04:21:00+00:00
# 48808 2018-12-30 01:27:00+00:00
# 48809 2018-12-30 01:27:00+00:00
# 48863 2018-12-31 19:22:00+00:00
# 49098 2017-06-24 22:45:00+00:00
# 49168 2017-06-25 17:42:00+00:00
# 49259 2017-06-27 07:35:00+00:00
# 49262 2017-06-27 08:06:00+00:00
# 49573 2017-06-16 05:17:00+00:00
# 49574 2017-06-16 03:03:00+00:00
# 49774 2017-07-04 06:20:00+00:00
# 49788 2017-07-04 15:43:00+00:00
#
#                                            StopCause ViolationNumber  \
# 32      REGISTRATION OR REQUIRED EQUIPMENT VIOLATION             UNK
# 54     MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 220    MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 380    MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 382    MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 490     REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24601
# 572     REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 581     REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 648    MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 770     REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 939    MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           21453
# 1098   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           21461
# 1103    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24602
# 1454    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           40001
# 1459    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 1735   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           21453
# 1741   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE     NOHEDLIGHTS
# 1742   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE     NOHEDLIGHTS
# 1743   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE     NOHEDLIGHTS
# 2105   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           24601
# 2257    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24400
# 2302    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION          5200V.
# 2366    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 2472    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 2506    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 2577   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE   DRIVINIGINIKE
# 2585   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 2761   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22350
# 2803   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22107
# 2897    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# ...                                              ...             ...
# 47495  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 47496  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22350
# 47497  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22350
# 47498  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 47499  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 47500   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION  WHITELIGHTTORE
# 47504  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 47586  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22107
# 47606   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 47693  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 47694   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 47764  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22107
# 47864  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 47866  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 47867  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23123
# 48181   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 48676  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE  DOORHINGEROKEN
# 48704  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE      FOUNDPLTES
# 48747   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 48808   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 48809   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 48863   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 49098  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 49168   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 49259  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE            4000
# 49262  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           24600
# 49573   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 49574  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           21453
# 49774   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 49788  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           21806
#
#          SpecialCondition                    Race Gender  ... StopYear  \
# 32         NOT APPLICABLE      OTHER/NOT APPARENT      M  ...     2017
# 54         NOT APPLICABLE                   WHITE      M  ...     2017
# 220    VEHICLE INSPECTION                HISPANIC      M  ...     2017
# 380        NOT APPLICABLE                   WHITE      M  ...     2017
# 382        NOT APPLICABLE                   WHITE      M  ...     2017
# 490        NOT APPLICABLE        AFRICAN AMERICAN      F  ...     2017
# 572        NOT APPLICABLE                HISPANIC      M  ...     2017
# 581        NOT APPLICABLE        AFRICAN AMERICAN      F  ...     2017
# 648        NOT APPLICABLE        AFRICAN AMERICAN      F  ...     2017
# 770        NOT APPLICABLE  ASIAN/PACIFIC ISLANDER      M  ...     2017
# 939        NOT APPLICABLE                   WHITE      M  ...     2017
# 1098       NOT APPLICABLE                HISPANIC      M  ...     2017
# 1103       NOT APPLICABLE                   WHITE      M  ...     2017
# 1454       NOT APPLICABLE                HISPANIC      M  ...     2017
# 1459       NOT APPLICABLE                HISPANIC      M  ...     2017
# 1735       NOT APPLICABLE        AFRICAN AMERICAN      F  ...     2017
# 1741       NOT APPLICABLE  ASIAN/PACIFIC ISLANDER      M  ...     2017
# 1742       NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2017
# 1743       NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2017
# 2105       NOT APPLICABLE                HISPANIC      M  ...     2017
# 2257       NOT APPLICABLE  ASIAN/PACIFIC ISLANDER      F  ...     2017
# 2302       NOT APPLICABLE                HISPANIC      M  ...     2017
# 2366       NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2017
# 2472       NOT APPLICABLE        AFRICAN AMERICAN      F  ...     2017
# 2506       NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2017
# 2577       NOT APPLICABLE                HISPANIC      F  ...     2017
# 2585       NOT APPLICABLE                   WHITE      F  ...     2017
# 2761       NOT APPLICABLE                HISPANIC      M  ...     2017
# 2803       NOT APPLICABLE      OTHER/NOT APPARENT      F  ...     2017
# 2897       NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2017
# ...                   ...                     ...    ...  ...      ...
# 47495      NOT APPLICABLE                   WHITE      M  ...     2018
# 47496      NOT APPLICABLE                   WHITE      M  ...     2018
# 47497      NOT APPLICABLE                   WHITE      M  ...     2018
# 47498      NOT APPLICABLE                   WHITE      M  ...     2018
# 47499      NOT APPLICABLE                   WHITE      M  ...     2018
# 47500      NOT APPLICABLE                   WHITE      M  ...     2018
# 47504      NOT APPLICABLE                   WHITE      M  ...     2018
# 47586      NOT APPLICABLE                HISPANIC      M  ...     2018
# 47606      NOT APPLICABLE      OTHER/NOT APPARENT      M  ...     2018
# 47693      NOT APPLICABLE      OTHER/NOT APPARENT      M  ...     2018
# 47694      NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2018
# 47764    CALL FOR SERVICE                   WHITE      F  ...     2018
# 47864      NOT APPLICABLE      OTHER/NOT APPARENT      F  ...     2018
# 47866      NOT APPLICABLE      OTHER/NOT APPARENT      F  ...     2018
# 47867      NOT APPLICABLE      OTHER/NOT APPARENT      M  ...     2018
# 48181      NOT APPLICABLE                HISPANIC      M  ...     2018
# 48676      NOT APPLICABLE                HISPANIC      F  ...     2018
# 48704      NOT APPLICABLE      OTHER/NOT APPARENT      M  ...     2018
# 48747      NOT APPLICABLE                   WHITE      M  ...     2018
# 48808      NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2018
# 48809      NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2018
# 48863      NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2018
# 49098      NOT APPLICABLE      OTHER/NOT APPARENT      M  ...     2017
# 49168      NOT APPLICABLE                HISPANIC      M  ...     2017
# 49259      NOT APPLICABLE                   WHITE      F  ...     2017
# 49262      NOT APPLICABLE                HISPANIC      F  ...     2017
# 49573      NOT APPLICABLE  ASIAN/PACIFIC ISLANDER      M  ...     2017
# 49574      NOT APPLICABLE        AFRICAN AMERICAN      M  ...     2017
# 49774      NOT APPLICABLE                   WHITE      F  ...     2017
# 49788      NOT APPLICABLE                   WHITE      F  ...     2017
#
#        StopDayofMonth  StopDayofWeek  StopHour  EntryMonth EntryYear  \
# 32                  4              1        16           7      2017
# 54                  7              4        23           7      2017
# 220                11              1        22           7      2017
# 380                13              1        16           7      2017
# 382                 2              4        16           7      2017
# 490                14              4        22           7      2017
# 572                26              0         1           7      2017
# 581                16              6        17           7      2017
# 648                17              0        22           7      2017
# 770                19              2        19           7      2017
# 939                20              3         8           7      2017
# 1098               22              5         0           7      2017
# 1103               22              5         3           7      2017
# 1454               26              2         8           7      2017
# 1459               26              2        10           7      2017
# 1735               28              4         0           7      2017
# 1741               28              4         1           7      2017
# 1742               28              4         2           7      2017
# 1743               28              4         2           7      2017
# 2105               11              4         1           8      2017
# 2257               13              6         0           8      2017
# 2302                1              1         1           8      2017
# 2366               15              1        23           8      2017
# 2472                8              5         1           8      2017
# 2506               17              3        22           8      2017
# 2577               18              4         0           8      2017
# 2585               18              4         6           8      2017
# 2761               21              0         1           8      2017
# 2803               22              1         1           8      2017
# 2897               23              2        23           8      2017
# ...               ...            ...       ...         ...       ...
# 47495              21              4         9           1      2019
# 47496              18              1         9           1      2019
# 47497              18              1         8           1      2019
# 47498              18              1         8           1      2019
# 47499              11              1         7           1      2019
# 47500               9              6        21           1      2019
# 47504               7              4        14           1      2019
# 47586               1              3        10           2      2019
# 47606               4              1        19           2      2019
# 47693              14              4        19           2      2019
# 47694              13              3         8           2      2019
# 47764               2              6        23           2      2019
# 47864              21              4        12           2      2019
# 47866              18              1        13           2      2019
# 47867              14              4        11           2      2019
# 48181               1              3        23          12      2018
# 48676              28              4        15          12      2018
# 48704              28              6        19          12      2018
# 48747              29              5        20          12      2018
# 48808              30              6        17          12      2018
# 48809              30              6        17          12      2018
# 48863              31              0        11          12      2018
# 49098              24              5        15           6      2017
# 49168              25              6        10           6      2017
# 49259              27              1         0           6      2017
# 49262              27              1         1           6      2017
# 49573              16              4        22           7      2017
# 49574              16              4        20           7      2017
# 49774               4              1        23           7      2017
# 49788               4              1         8           7      2017
#
#       EntryDayofMonth EntryDayofWeek  EntryHour   Age
# 32                  7              4         23  31.0
# 54                  7              4          3  44.0
# 220                11              1         22  22.0
# 380                13              3         10  57.0
# 382                13              3         10  27.0
# 490                14              4         22  20.0
# 572                15              5          5  23.0
# 581                16              6         17  37.0
# 648                17              0         23  33.0
# 770                19              2         21  49.0
# 939                20              3          8  22.0
# 1098               22              5          0  28.0
# 1103               22              5          4  20.0
# 1454               26              2          8  37.0
# 1459               26              2         11  46.0
# 1735               28              4          0  27.0
# 1741               28              4          2  31.0
# 1742               28              4          2  58.0
# 1743               28              4          2  58.0
# 2105               11              4          2  49.0
# 2257               13              6          5  26.0
# 2302               14              0          2  27.0
# 2366               15              1         23  30.0
# 2472               16              2         13  26.0
# 2506               17              3         23  55.0
# 2577               18              4          0  43.0
# 2585               18              4          6  25.0
# 2761               21              0          1  58.0
# 2803               22              1          1  30.0
# 2897               23              2         23  33.0
# ...               ...            ...        ...   ...
# 47495              26              5         21  38.0
# 47496              26              5         21  38.0
# 47497              26              5         21  38.0
# 47498              26              5         21  38.0
# 47499              26              5         21  38.0
# 47500              26              5         21  38.0
# 47504              26              5         21  48.0
# 47586               1              4         20  77.0
# 47606               2              5         16  30.0
# 47693               5              1         17  37.0
# 47694               5              1         17  56.0
# 47764               8              4          6  22.0
# 47864              21              3         11  45.0
# 47866              21              3         11  19.0
# 47867              21              3         11  43.0
# 48181              22              5         19  26.0
# 48676              29              5         16  44.0
# 48704              29              5         17  19.0
# 48747              29              5         20  27.0
# 48808              30              6         17  28.0
# 48809              30              6         17  28.0
# 48863              31              0         11  21.0
# 49098              24              5         15  38.0
# 49168              25              6         10  20.0
# 49259              27              1          0  33.0
# 49262              27              1          1  20.0
# 49573               1              5          0  28.0
# 49574               1              5          0  20.0
# 49774               4              1         23  19.0
# 49788               4              1          8  30.0
#
# [618 rows x 46 columns]

# %%
stopdata['ExitVehicle'].value_counts()
# Out:
# NO     41500
# YES     7756
# Name: ExitVehicle, dtype: int64

# %% [markdown]
# We will change the null values to the mode, which is NO, and then map this to boolean data - False for "NO" and True for "YES"

# %%
def exitvehiclefix(data):
    data.loc[data['ExitVehicle'].isna(), 'ExitVehicle'] = False
    data['ExitVehicle'] = data['ExitVehicle'].replace({'NO': False, 'YES': True})
    return data

# %%
stopdata = stop_data()
stopdata = exitvehiclefix(stopdata)

# %% [markdown]
# ### ResultCitation

# %%
stopdata['ResultCitation'].value_counts()
# Out:
# False    31415
# True     18459
# Name: ResultCitation, dtype: int64

# %% [markdown]
# ### Detention Duration

# %%
print(stopdata['DetentionDuration'].value_counts()[:10])

# %%
stopdata['ResultReport'].value_counts()
# Out:
# False    48424
# True      1450
# Name: ResultReport, dtype: int64

# %%
stopdata['LimitedLanguage'].value_counts()
# Out:
# False    48728
# True      1146
# Name: LimitedLanguage, dtype: int64

# %% [markdown]
# ### Consent Granted and Consent Requested

# %% [markdown]
# Consent Granted and Consent Requested

# %%
stopdata.loc[stopdata['ConsentRequested'] == 'PAROLE/PROBATION']
# Out:
#           Idx CitationNumber                 EntryDate StopType  \
# 71     437869      CS0011520  2017-07-07T07:57:00.000Z  VEHICLE
# 4697   436335      CS0137525  2017-06-14T21:22:00.000Z  VEHICLE
# 5335   445290      CS0072023  2017-09-21T09:37:00.000Z  VEHICLE
# 5749   445711      CS0063042  2017-09-26T00:45:00.000Z  VEHICLE
# 8397   451375      CS0177582  2017-11-14T22:16:00.000Z  VEHICLE
# 12360  446324      CS0063044  2017-10-02T23:40:00.000Z  VEHICLE
# 14129  448093      CS0019122  2017-10-13T17:10:00.000Z  VEHICLE
# 14131  448095      CS0019123  2017-10-13T17:50:00.000Z  VEHICLE
# 14132  448096      CS0019124  2017-10-13T20:36:00.000Z  VEHICLE
# 15778  455768      CS0154589  2018-01-05T10:50:00.000Z  VEHICLE
# 16229  457219      CS0052102  2018-01-11T08:19:00.000Z  VEHICLE
# 16878  457868      CS0063060  2018-01-15T21:51:00.000Z  VEHICLE
# 17404  454393      CS0107028  2017-12-20T01:11:00.000Z  VEHICLE
# 17715  454704      CS0063049  2017-12-17T19:43:00.000Z  VEHICLE
# 17962  454951      CS0060055  2017-12-28T01:14:00.000Z  VEHICLE
# 19949  458939      CS0144168  2018-01-26T06:03:00.000Z  VEHICLE
# 20280  461270      CS0153624  2018-02-16T07:08:00.000Z  VEHICLE
# 20380  461370      CS0063069  2018-02-12T19:04:00.000Z  VEHICLE
# 20520  461510      CS0153627  2018-02-19T04:51:00.000Z  VEHICLE
# 22550  460540      CS0153620  2018-02-04T12:51:00.000Z  VEHICLE
# 22551  460541      CS0153621  2018-02-10T13:06:00.000Z  VEHICLE
# 23401  463394      CS0153632  2018-03-10T06:55:00.000Z  VEHICLE
# 25663  465652      CS0063078  2018-03-18T20:16:00.000Z  VEHICLE
# 27150  467140      CS0063083  2018-04-10T18:28:00.000Z  VEHICLE
# 27151  467141      CS0063083  2018-04-10T18:28:00.000Z  VEHICLE
# 27159  467149      CS0063081  2018-04-08T13:56:00.000Z  VEHICLE
# 27160  467150      CS0063081  2018-04-08T13:56:00.000Z  VEHICLE
# 35199  478186      CS0147613  2018-08-12T01:51:00.000Z  VEHICLE
# 36428  479418      CS0153650  2018-08-24T04:46:00.000Z  VEHICLE
# 40939  485925      CS0153653  2018-10-11T05:38:00.000Z  VEHICLE
# 44337  486323      CS0124173  2018-09-09T21:20:00.000Z  VEHICLE
# 48055  494160      CS0020895  2018-12-19T16:17:00.000Z  VEHICLE
#
#                         StopDTS  \
# 71     2017-07-07T07:57:00.000Z
# 4697   2017-06-14T21:22:00.000Z
# 5335   2017-09-21T09:37:00.000Z
# 5749   2017-09-26T00:45:00.000Z
# 8397   2017-11-14T22:16:00.000Z
# 12360  2017-10-02T23:40:00.000Z
# 14129  2017-10-13T17:10:00.000Z
# 14131  2017-10-13T17:50:00.000Z
# 14132  2017-10-13T20:36:00.000Z
# 15778  2018-01-05T10:50:00.000Z
# 16229  2018-01-11T08:19:00.000Z
# 16878  2018-01-15T21:51:00.000Z
# 17404  2017-12-20T01:11:00.000Z
# 17715  2017-12-17T19:43:00.000Z
# 17962  2017-12-28T01:14:00.000Z
# 19949  2018-01-26T06:03:00.000Z
# 20280  2018-02-16T07:08:00.000Z
# 20380  2018-02-12T19:04:00.000Z
# 20520  2018-02-19T04:51:00.000Z
# 22550  2018-02-04T12:51:00.000Z
# 22551  2018-02-10T13:06:00.000Z
# 23401  2018-03-10T06:55:00.000Z
# 25663  2018-03-18T20:16:00.000Z
# 27150  2018-04-10T18:28:00.000Z
# 27151  2018-04-10T18:28:00.000Z
# 27159  2018-04-08T13:56:00.000Z
# 27160  2018-04-08T13:56:00.000Z
# 35199  2018-08-12T01:51:00.000Z
# 36428  2018-08-24T04:46:00.000Z
# 40939  2018-10-11T05:38:00.000Z
# 44337  2018-09-09T21:20:00.000Z
# 48055  2018-12-19T16:17:00.000Z
#
#                                            StopCause ViolationNumber  \
# 71      REGISTRATION OR REQUIRED EQUIPMENT VIOLATION      4000(A)(1)
# 4697                                  NOT APPLICABLE         UNKNOWN
# 5335    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           5200A
# 5749    REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           4000A
# 8397   MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 12360   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           4000A
# 14129  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           14601
# 14131  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           14601
# 14132  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           14601
# 15778  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22350
# 16229  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE        22450(A)
# 16878  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE            5200
# 17404   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION       4000A CVC
# 17715                           STATE CODE VIOLATION           26710
# 17962  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE          21453A
# 19949  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22350
# 20280   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 20380   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24600
# 20520   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           4000A
# 22550   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 22551   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            5200
# 23401                                 NOT APPLICABLE           4000A
# 25663   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4464
# 27150   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           26710
# 27151   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           26710
# 27159   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           27151
# 27160   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           27151
# 35199   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 36428  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           23103
# 40939   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24600
# 44337   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           4000A
# 48055  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           21209
#
#                          SpecialCondition              Race Gender  ...  \
# 71                         NOT APPLICABLE  AFRICAN AMERICAN      M  ...
# 4697                       NOT APPLICABLE  AFRICAN AMERICAN      F  ...
# 5335                       NOT APPLICABLE  AFRICAN AMERICAN      M  ...
# 5749                       NOT APPLICABLE  AFRICAN AMERICAN      M  ...
# 8397                       NOT APPLICABLE          HISPANIC      M  ...
# 12360                      NOT APPLICABLE             WHITE      F  ...
# 14129  PRE-EXISTING KNOWLEDGE/INFORMATION             WHITE      M  ...
# 14131  PRE-EXISTING KNOWLEDGE/INFORMATION          HISPANIC      M  ...
# 14132  PRE-EXISTING KNOWLEDGE/INFORMATION             WHITE      F  ...
# 15778                      NOT APPLICABLE          HISPANIC      M  ...
# 16229                      NOT APPLICABLE             WHITE      F  ...
# 16878                      NOT APPLICABLE  AFRICAN AMERICAN      M  ...
# 17404                      NOT APPLICABLE             WHITE      F  ...
# 17715                      NOT APPLICABLE          HISPANIC      M  ...
# 17962                      NOT APPLICABLE  AFRICAN AMERICAN      F  ...
# 19949                      NOT APPLICABLE          HISPANIC      M  ...
# 20280                      NOT APPLICABLE          HISPANIC      M  ...
# 20380                      NOT APPLICABLE  AFRICAN AMERICAN      M  ...
# 20520                      NOT APPLICABLE             WHITE      M  ...
# 22550                      NOT APPLICABLE          HISPANIC      M  ...
# 22551                      NOT APPLICABLE          HISPANIC      F  ...
# 23401                      NOT APPLICABLE          HISPANIC      M  ...
# 25663                      NOT APPLICABLE             WHITE      M  ...
# 27150                      NOT APPLICABLE       ASIAN OTHER      M  ...
# 27151                      NOT APPLICABLE       ASIAN OTHER      M  ...
# 27159                      NOT APPLICABLE          HISPANIC      M  ...
# 27160                      NOT APPLICABLE          HISPANIC      M  ...
# 35199                      NOT APPLICABLE       ASIAN OTHER      M  ...
# 36428                      NOT APPLICABLE          HISPANIC      M  ...
# 40939                      NOT APPLICABLE           UNKNOWN      M  ...
# 44337                      NOT APPLICABLE       EAST INDIAN      M  ...
# 48055                      NOT APPLICABLE          HISPANIC      M  ...
#
#        ResultCitation  ResultArrest  ResultReport  ResultAdvised  ResultFC  \
# 71               True         False         False          False     False
# 4697             True         False         False          False     False
# 5335             True         False         False          False     False
# 5749             True         False          True          False     False
# 8397             True         False          True          False     False
# 12360            True         False         False          False     False
# 14129            True          True          True          False     False
# 14131            True          True          True           True     False
# 14132            True          True          True           True     False
# 15778            True         False         False          False     False
# 16229            True         False          True          False      True
# 16878            True         False          True          False     False
# 17404            True          True          True          False     False
# 17715            True         False         False          False     False
# 17962            True         False         False          False     False
# 19949           False         False         False           True      True
# 20280            True         False         False          False      True
# 20380            True         False         False          False     False
# 20520            True         False         False          False      True
# 22550            True          True         False          False      True
# 22551            True          True         False          False      True
# 23401            True         False         False          False      True
# 25663            True         False         False          False     False
# 27150            True         False         False          False     False
# 27151            True         False         False          False     False
# 27159            True         False         False          False     False
# 27160            True         False         False          False     False
# 35199            True         False         False           True      True
# 36428            True          True          True          False      True
# 40939            True         False         False          False      True
# 44337            True         False         False          False     False
# 48055            True         False          True          False     False
#
#        CadCallNumber DetentionDuration OfficerAbra LimitedLanguage    FID
# 71         17-191590                60        4442           False   2072
# 4697       17-167047                30        3728           False    698
# 5335       17-271805                30        4342           False   8336
# 5749       17-276591                30        4137           False   8750
# 8397       17-327991                30        4093           False  13398
# 12360      17-284112                30        4137           False   9361
# 14129      17-294738                15        3070           False  10130
# 14131      17-294712                15        3070           False  10132
# 14132      17-294936                15        3070           False  10133
# 15778      18-004952                30        4282           False  17779
# 16229      18-009613                60        4511           False  18230
# 16878      18-014365                30        4137           False  18879
# 17404      17-362571                45        3522           False  16405
# 17715      17-360343                30        4137           False  16716
# 17962      17-370120                30        4447           False  16963
# 19949      18-025368                15        4192           False  19950
# 20280      18-048955                20        4444           False  22281
# 20380      18-044867                25        4137           False  22381
# 20520      18-052321                20        4444           False  22521
# 22550      18-042557                25        4444           False  21551
# 22551      18-042557                25        4444           False  21552
# 23401      18-073001                20        4444           False  24402
# 25663      18-082059                30        4137           False  25664
# 27150      18-105032                30        4137           False  27151
# 27151      18-105032                30        4137           False  27152
# 27159      18-102825                30        4137           False  27160
# 27160      18-102825                30        4137           False  27161
# 35199      18-252989                20        4111           False  36200
# 36428      18-267973                20        4444           False  37429
# 40939      18-324538                15        4444           False  41940
# 44337      18-328164                30        4490           False  42338
# 48055      18-400378                30        4093           False  48182
#
# [32 rows x 36 columns]

# %% [markdown]
# ### CadCallNumber
#
# We will change this to a boolean column, which states if the CadCallNumber was one of the top two in the value counts

# %%
stopdata['CadCallNumber'].value_counts()[:5]
# Out:
# 18-000001    81
# 17-005000    15
# 18-000007     7
# 18-000000     6
# 18-000011     6
# Name: CadCallNumber, dtype: int64

# %%
def cadcallnumberfix(data):
    data['CadCallNumber'] = data['CadCallNumber'].map({'18-000001': True, '17-005000': True })
    data.loc[data['CadCallNumber'].isna(), 'CadCallNumber'] = False
    return data

# %%
stopdata = cadcallnumberfix(stopdata)

# %%
stopdata['CadCallNumber'].value_counts()
# Out:
# False    49778
# True        96
# Name: CadCallNumber, dtype: int64

# %% [markdown]
# ### Authority

# %%
stopdata['Authority'].value_counts()
# Out:
# NOT APPLICABLE        43888
# PAROLE/PROBATION       4236
# PROBABLE CAUSE          607
# TOW INVENTORY           418
# TERRY CURSORY           393
# INCIDENT TO ARRE        311
# INCIDENT TO ARREST       21
# Name: Authority, dtype: int64

# %% [markdown]
# "INCIDENT TO ARRE" and "INCIDENT TO ARREST" are the same thing so lets "standardize" this value accordingly.

# %%
def authorityfix(data):
    data.loc[data['Authority'] == 'INCIDENT TO ARRE', 'Authority'] = "INCIDENT TO ARREST"
    return data

# %%
stopdata = authorityfix(stopdata)

# %%
stopdata['Authority'].value_counts()
# Out:
# NOT APPLICABLE        43888
# PAROLE/PROBATION       4236
# PROBABLE CAUSE          607
# TOW INVENTORY           418
# TERRY CURSORY           393
# INCIDENT TO ARREST      332
# Name: Authority, dtype: int64

# %% [markdown]
# ### Columns we don't need

# %% [markdown]
# FID, Idx  have unique values, so we will drop these columns. In addition, the Stoptype column has only one entry, vehicle, so this will be removed as well. Other columns, like the original date columns will be removed as well.

# %%
def removecolumns(data):
    cols = [col for col in data.columns if col not in ['FID', 'Idx', 'StopType']]
    data = data[cols]
    return data

# %%
stopdata = removecolumns(stopdata)

# %%
stopdata.columns
# Out:
# Index(['CitationNumber', 'EntryDate', 'StopDTS', 'StopCause',
#        'ViolationNumber', 'SpecialCondition', 'Race', 'Gender', 'BirthYear',
#        'ExitVehicle', 'PassengerCount', 'SearchDriver', 'SearchPassenger',
#        'SearchVehicle', 'Authority', 'ConsentRequested', 'ConsentGranted',
#        'FSWeapons', 'FSDrugs', 'FSCash', 'FSVehicle', 'FSAlcohol',
#        'FSOtherProperty', 'FSNothing', 'ResultCitation', 'ResultArrest',
#        'ResultReport', 'ResultAdvised', 'ResultFC', 'CadCallNumber',
#        'DetentionDuration', 'OfficerAbra', 'LimitedLanguage'],
#       dtype='object')

# %%
def convert_
# Out:
#   File "<ipython-input-58-e97963ec4fd7>", line 1
#     def convert_
#                 ^
# SyntaxError: invalid syntax

# %%
def process_data_gm1(data):

    data = (
        data
        # Clean/Tranform Data
        .pipe(citationnumberfix)
        .pipe(convertdatecolumns, 'EntryDate')
        .pipe(convertdatecolumns, 'StopDTS')
        .pipe(violationnumberfix)
        .pipe(birthyearfix)
        .pipe(passengercountfix)
        .pipe(exitvehiclefix)
        .pipe(cadcallnumberfix)
        .pipe(authorityfix)
    
    
        # Remove columns
     
        .pipe(removecolumns)
     
        
     
    ) 
    
    return data

# %%
stopdata = stop_data()
stopdata = process_data_gm1(stopdata)
stopdata.head(5)
# Out:
#    Citation                 EntryDate                   StopDTS  \
# 0     False 2017-07-06 05:04:02+00:00 2017-07-06 04:58:00+00:00
# 1     False 2017-07-06 05:46:55+00:00 2017-07-06 05:41:00+00:00
# 2     False 2017-07-06 06:05:59+00:00 2017-07-06 05:57:00+00:00
# 3     False 2017-07-06 06:06:16+00:00 2017-07-06 05:13:00+00:00
# 4     False 2017-07-06 06:15:39+00:00 2017-07-06 06:02:00+00:00
#
#                                        StopCause ViolationNumber  \
# 0  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22108
# 1  MOVING OR HAZARDOUS VIOLATION OF VEHICLE CODE           22450
# 2   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24616
# 3   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION            4000
# 4   REGISTRATION OR REQUIRED EQUIPMENT VIOLATION           24600
#
#   SpecialCondition                    Race Gender  ExitVehicle  \
# 0   NOT APPLICABLE  ASIAN/PACIFIC ISLANDER      F        False
# 1   NOT APPLICABLE        AFRICAN AMERICAN      F        False
# 2   NOT APPLICABLE        AFRICAN AMERICAN      M        False
# 3   NOT APPLICABLE        AFRICAN AMERICAN      F        False
# 4   NOT APPLICABLE        AFRICAN AMERICAN      M        False
#
#    PassengerCount  ...  EntryYear  EntryDayofMonth  EntryDayofWeek EntryHour  \
# 0               1  ...       2017                6               3        22
# 1               0  ...       2017                6               3        22
# 2               1  ...       2017                6               3        23
# 3               0  ...       2017                6               3        23
# 4               0  ...       2017                6               3        23
#
#   StopMonth StopYear  StopDayofMonth  StopDayofWeek  StopHour   Age
# 0         7     2017               6              3        21  24.0
# 1         7     2017               6              3        22  23.0
# 2         7     2017               6              3        22  28.0
# 3         7     2017               6              3        22  48.0
# 4         7     2017               6              3        23  21.0
#
# [5 rows x 43 columns]

# %%
stopdata.to_csv("cleaned_eda.csv")

# %% [markdown]
# ## Cleaning for Machine Learning Classification
#
# The pipeline above will make our data perfect for exploring our data and extracting insights through EDA. However, the data above is not the best for training for machine learning- we cannot have categorical features. To fix this, we will do one hot encoding to transform our categorical data.

# %%
def onehotencoding(data):
    data['OfficerAbra'] = data['OfficerAbra'].astype(str)
    return pd.get_dummies(data)

# %%
def removecolumns2(data):
    cols = [col for col in data.columns if col not in ['FID', 'Idx', 'StopType', 'EntryDate', 'StopDTS']]
    data = data[cols]
    return data

# %%
def process_data_gm2(data):

    data = (
        data
        # Clean Data
        .pipe(citationnumberfix)
        .pipe(convertdatecolumns, 'EntryDate')
        .pipe(convertdatecolumns, 'StopDTS')
        .pipe(violationnumberfix)
        .pipe(birthyearfix)
        .pipe(passengercountfix)
        .pipe(exitvehiclefix)
        .pipe(cadcallnumberfix)
        .pipe(authorityfix)
    
        # Remove Columns
     
        .pipe(removecolumns2)
        
        #One Hot Encode
        
        .pipe(onehotencoding)
        
    ) 
    
    return data

# %%
stopdata = stop_data()
ml = process_data_gm2(stopdata)
ml.to_csv("ml.csv", index=False)
